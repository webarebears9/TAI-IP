# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("C:\\Users\\anilb\\OneDrive\\Desktop\\clg\\tech a intern\\owid-covid-data.csv")
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  24/2/2020          5.0        5.0
# 1           AFG      Asia  Afghanistan  25/2/2020          5.0        0.0
# 2           AFG      Asia  Afghanistan  26/2/2020          5.0        0.0
# 3           AFG      Asia  Afghanistan  27/2/2020          5.0        0.0
# 4           AFG      Asia  Afghanistan  28/2/2020          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 176219      ZWE    Africa     Zimbabwe  30/3/2022     246182.0      140.0
# 176220      ZWE    Africa     Zimbabwe  31/3/2022     246286.0      104.0
# 176221      ZWE    Africa     Zimbabwe   1/4/2022     246414.0      128.0
# 176222      ZWE    Africa     Zimbabwe   2/4/2022     246481.0       67.0
# 176223      ZWE    Africa     Zimbabwe   3/4/2022     246525.0       44.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
os.chdir("C:\\Users\\anilb\\OneDrive\\Desktop\\clg\\tech a intern\\")

# %%
stats = pd.read_csv('owid-covid-data.csv')
stats
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  24/2/2020          5.0        5.0
# 1           AFG      Asia  Afghanistan  25/2/2020          5.0        0.0
# 2           AFG      Asia  Afghanistan  26/2/2020          5.0        0.0
# 3           AFG      Asia  Afghanistan  27/2/2020          5.0        0.0
# 4           AFG      Asia  Afghanistan  28/2/2020          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 176219      ZWE    Africa     Zimbabwe  30/3/2022     246182.0      140.0
# 176220      ZWE    Africa     Zimbabwe  31/3/2022     246286.0      104.0
# 176221      ZWE    Africa     Zimbabwe   1/4/2022     246414.0      128.0
# 176222      ZWE    Africa     Zimbabwe   2/4/2022     246481.0       67.0
# 176223      ZWE    Africa     Zimbabwe   3/4/2022     246525.0       44.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
stats.shape
# Out:
# (176224, 67)

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176224 entries, 0 to 176223
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    176224 non-null  object
#  1   continent                                   165891 non-null  object
#  2   location                                    176224 non-null  object
#  3   date                                        176224 non-null  object
#  4   total_cases                                 169905 non-null  float64
#  5   new_cases                                   169680 non-null  float64
#  6   new_cases_smoothed                          167685 non-null  float64
#  7   total_deaths                                151828 non-null  float64
#  8   new_deaths                                  151827 non-null  float64
# ...

# %%
stats.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24/2/2020          5.0        5.0
# 1      AFG      Asia  Afghanistan  25/2/2020          5.0        0.0
# 2      AFG      Asia  Afghanistan  26/2/2020          5.0        0.0
# 3      AFG      Asia  Afghanistan  27/2/2020          5.0        0.0
# 4      AFG      Asia  Afghanistan  28/2/2020          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
stats = pd.DataFrame(stats)
stats
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  24/2/2020          5.0        5.0
# 1           AFG      Asia  Afghanistan  25/2/2020          5.0        0.0
# 2           AFG      Asia  Afghanistan  26/2/2020          5.0        0.0
# 3           AFG      Asia  Afghanistan  27/2/2020          5.0        0.0
# 4           AFG      Asia  Afghanistan  28/2/2020          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 176219      ZWE    Africa     Zimbabwe  30/3/2022     246182.0      140.0
# 176220      ZWE    Africa     Zimbabwe  31/3/2022     246286.0      104.0
# 176221      ZWE    Africa     Zimbabwe   1/4/2022     246414.0      128.0
# 176222      ZWE    Africa     Zimbabwe   2/4/2022     246481.0       67.0
# 176223      ZWE    Africa     Zimbabwe   3/4/2022     246525.0       44.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
city = stats['continent'].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=city.index, y=city.values)
plt.title('Count of People in each Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
